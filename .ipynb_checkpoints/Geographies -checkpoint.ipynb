# %% [markdown]
# # Geography at Different Levels
# This notebook demonstrates how to tackle geographies defined at various levels. For this purpose we will be using some Lanarkshire GPs as well as some hypothetical ones.

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import shapely
from shapely.ops import unary_union
from shapely.geometry import mapping, Polygon

# %% [markdown]
# ## Districts and Sectors
# Firstly, we read in shape files for districts and sectors.

# %%
districts = gpd.read_file('~/Desktop/GP_Boundaries/District_22_1/District_22_1.shp')

# %%
sectors = gpd.read_file('~/Desktop/GP_Boundaries/Sector_22_1/Sector_22_1.shp')

# %% [markdown]
# Check the first few items of the files.

# %%
districts.head(5) # districts
# Out:
#    OBJECTID District    Shape_Leng    Shape_Area  \
# 0         1     AB10  17466.667741  4.591592e+06
# 1         2     AB11  26086.506732  5.396370e+06
# 2         3     AB12  73839.045489  7.299857e+07
# 3         4     AB13  15847.217768  8.770372e+06
# 4         5     AB14  27250.316419  1.754676e+07
#
#                                             geometry
# 0  POLYGON ((394256.974 806666.497, 394264.000 80...
# 1  MULTIPOLYGON (((393211.114 805537.072, 393207....
# 2  MULTIPOLYGON (((396494.604 802552.201, 396491....
# 3  POLYGON ((386014.000 803318.000, 385991.953 80...
# 4  POLYGON ((383220.204 804258.703, 383230.799 80...

# %%
sectors.head(5) # sectors
# Out:
#    OBJECTID  Sector    Shape_Leng    Shape_Area  \
# 0         1  AB10 1   7131.510278  7.130118e+05
# 1         2  AB10 6  12335.212789  1.505824e+06
# 2         3  AB10 7  11424.566022  2.372756e+06
# 3         4  AB11 5  13781.980960  1.219767e+06
# 4         5  AB11 6   7083.623538  7.724720e+05
#
#                                             geometry
# 0  POLYGON ((394256.974 806666.497, 394264.000 80...
# 1  POLYGON ((393348.999 805786.000, 393364.000 80...
# 2  POLYGON ((393209.011 805132.125, 393206.363 80...
# 3  POLYGON ((395211.917 806599.168, 395275.000 80...
# 4  MULTIPOLYGON (((393211.114 805537.072, 393207....

# %% [markdown]
# Check the dimension.

# %%
print(districts.shape)
print(sectors.shape)
# Out:
# (444, 5)
# (958, 5)

# %% [markdown]
# ## GP Information
# Now we read in our GP information. Some of the practices are from Lanarkshire. For the purpose of testing, we have included two hypothetical practices. For simplicity, some edits have also been made to the Lanarkshire practices to ensure that they include, for example, a whole district, rather than just a portion of it.

# %%
hypo = pd.read_excel('./Geography.xls')

# %%
hypo = hypo.rename(columns = {'Practice Area as defiend in GMS Contract/17C Agreement':  'Areas'}) # rename

# %%
hypo
# Out:
#    Ref  Former GG&C Code  Practice Code                    Practice Name  \
# 0    2           46536.0          60073       Nalagatla Medical Practice
# 1   12           49642.0          60177  The Craigallian Avenue Practice
# 2    4           49002.0          60092            The Stonelaw Practice
# 3   15           49799.0          60209          Ardoch Medical Practice
# 4  100               NaN          66666                 Hypothetical One
# 5  101               NaN          66667                 Hypothetical Two
#
#   Contract Practice Town                 Locality             Unit   HSCP  \
# 0      17J        Stepps           North Locality  North West Unit  North
# 1      17J    Cambuslang  Cambuslang / Rutherglen  South West Unit  South
# 2      17J    Rutherglen  Cambuslang / Rutherglen  South West Unit  South
# 3      17J    Cambuslang  Cambuslang / Rutherglen  South West Unit  South
# 4      17J    Cambuslang  Cambuslang / Rutherglen  South West Unit  South
# 5      17J    Cambuslang  Cambuslang / Rutherglen  South West Unit  South
#
#                                                Areas
# 0          G33 6,G33 1,G66 5,G67 4,G69 0,G69 8,G69 9
# 1                                        G72 7,G72 8
# 2  G40,G42,G44,G45,G60,G61,G62,G63,G64,G65,G66,G6...
# 3                                                G72
# 4                          G72,G73,G69 6,G69 7,G71 5
# 5                    G74 1,G74 2,G74 3,G74 4,G68,G69

# %% [markdown]
# ### Seperating the areas
# Notice the areas are seperated by commas for a practice. We split them into individual rows.

# %%
hyposplit = hypo.set_index(['Practice Code','Practice Name']).Areas.str.split(',',expand=True).stack().reset_index().rename(columns={0:'Areas'})

# %%
hyposplit.head(5)
# Out:
#    Practice Code               Practice Name  level_2  Areas
# 0          60073  Nalagatla Medical Practice        0  G33 6
# 1          60073  Nalagatla Medical Practice        1  G33 1
# 2          60073  Nalagatla Medical Practice        2  G66 5
# 3          60073  Nalagatla Medical Practice        3  G67 4
# 4          60073  Nalagatla Medical Practice        4  G69 0

# %%
hyposplit
# Out:
#     Practice Code                    Practice Name  level_2  Areas
# 0           60073       Nalagatla Medical Practice        0  G33 6
# 1           60073       Nalagatla Medical Practice        1  G33 1
# 2           60073       Nalagatla Medical Practice        2  G66 5
# 3           60073       Nalagatla Medical Practice        3  G67 4
# 4           60073       Nalagatla Medical Practice        4  G69 0
# 5           60073       Nalagatla Medical Practice        5  G69 8
# 6           60073       Nalagatla Medical Practice        6  G69 9
# 7           60177  The Craigallian Avenue Practice        0  G72 7
# 8           60177  The Craigallian Avenue Practice        1  G72 8
# 9           60092            The Stonelaw Practice        0    G40
# 10          60092            The Stonelaw Practice        1    G42
# 11          60092            The Stonelaw Practice        2    G44
# 12          60092            The Stonelaw Practice        3    G45
# 13          60092            The Stonelaw Practice        4    G60
# 14          60092            The Stonelaw Practice        5    G61
# 15          60092            The Stonelaw Practice        6    G62
# 16          60092            The Stonelaw Practice        7    G63
# 17          60092            The Stonelaw Practice        8    G64
# 18          60092            The Stonelaw Practice        9    G65
# 19          60092            The Stonelaw Practice       10    G66
# 20          60092            The Stonelaw Practice       11    G67
# 21          60092            The Stonelaw Practice       12    G68
# 22          60092            The Stonelaw Practice       13    G69
# 23          60092            The Stonelaw Practice       14    G71
# 24          60092            The Stonelaw Practice       15    G72
# 25          60092            The Stonelaw Practice       16    G73
# 26          60092            The Stonelaw Practice       17    G76
# 27          60209          Ardoch Medical Practice        0    G72
# 28          66666                 Hypothetical One        0    G72
# 29          66666                 Hypothetical One        1    G73
# 30          66666                 Hypothetical One        2  G69 6
# 31          66666                 Hypothetical One        3  G69 7
# 32          66666                 Hypothetical One        4  G71 5
# 33          66667                 Hypothetical Two        0  G74 1
# 34          66667                 Hypothetical Two        1  G74 2
# 35          66667                 Hypothetical Two        2  G74 3
# 36          66667                 Hypothetical Two        3  G74 4
# 37          66667                 Hypothetical Two        4    G68
# 38          66667                 Hypothetical Two        5    G69

# %% [markdown]
# ### Distinguishing between districts and areas
# The areas consist of both postcode districts and sectors. We want seperate columns for them. As seen above, postcode sectors contain an extra space within the string. We can use this property to seperate them from districts.

# %%
mask = hyposplit.Areas.str.contains(" ")

# %% [markdown]
# The $\texttt{mask}$ object above contains boolean results (True/False). True means there is a space in thes string and is therefore a postcode sector.

# %% [markdown]
# We then have to use the results above to extract the districts and sectors, and create columns for them. We can also remove the original column now.

# %%
hyposplit['District'] = hyposplit[mask==False]['Areas'] # Create a District column
hyposplit['Sector'] = hyposplit[mask]['Areas']          # Create a Sector column
hyposplit = hyposplit.drop('level_2',1)                 # Drop irelevant columns
hyposplit = hyposplit.drop('Areas',1)
# Out:
# C:\Users\yeehil01\AppData\Local\Temp\ipykernel_22492\2133560992.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   hyposplit = hyposplit.drop('level_2',1)
# C:\Users\yeehil01\AppData\Local\Temp\ipykernel_22492\2133560992.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   hyposplit = hyposplit.drop('Areas',1)

# %%
hyposplit
# Out:
#     Practice Code                    Practice Name District Sector
# 0           60073       Nalagatla Medical Practice      NaN  G33 6
# 1           60073       Nalagatla Medical Practice      NaN  G33 1
# 2           60073       Nalagatla Medical Practice      NaN  G66 5
# 3           60073       Nalagatla Medical Practice      NaN  G67 4
# 4           60073       Nalagatla Medical Practice      NaN  G69 0
# 5           60073       Nalagatla Medical Practice      NaN  G69 8
# 6           60073       Nalagatla Medical Practice      NaN  G69 9
# 7           60177  The Craigallian Avenue Practice      NaN  G72 7
# 8           60177  The Craigallian Avenue Practice      NaN  G72 8
# 9           60092            The Stonelaw Practice      G40    NaN
# 10          60092            The Stonelaw Practice      G42    NaN
# 11          60092            The Stonelaw Practice      G44    NaN
# 12          60092            The Stonelaw Practice      G45    NaN
# 13          60092            The Stonelaw Practice      G60    NaN
# 14          60092            The Stonelaw Practice      G61    NaN
# 15          60092            The Stonelaw Practice      G62    NaN
# 16          60092            The Stonelaw Practice      G63    NaN
# 17          60092            The Stonelaw Practice      G64    NaN
# 18          60092            The Stonelaw Practice      G65    NaN
# 19          60092            The Stonelaw Practice      G66    NaN
# 20          60092            The Stonelaw Practice      G67    NaN
# 21          60092            The Stonelaw Practice      G68    NaN
# 22          60092            The Stonelaw Practice      G69    NaN
# 23          60092            The Stonelaw Practice      G71    NaN
# 24          60092            The Stonelaw Practice      G72    NaN
# 25          60092            The Stonelaw Practice      G73    NaN
# 26          60092            The Stonelaw Practice      G76    NaN
# 27          60209          Ardoch Medical Practice      G72    NaN
# 28          66666                 Hypothetical One      G72    NaN
# 29          66666                 Hypothetical One      G73    NaN
# 30          66666                 Hypothetical One      NaN  G69 6
# 31          66666                 Hypothetical One      NaN  G69 7
# 32          66666                 Hypothetical One      NaN  G71 5
# 33          66667                 Hypothetical Two      NaN  G74 1
# 34          66667                 Hypothetical Two      NaN  G74 2
# 35          66667                 Hypothetical Two      NaN  G74 3
# 36          66667                 Hypothetical Two      NaN  G74 4
# 37          66667                 Hypothetical Two      G68    NaN
# 38          66667                 Hypothetical Two      G69    NaN

# %% [markdown]
# Check the shape of the data.

# %%
hyposplit.shape
# Out:
# (39, 4)

# %% [markdown]
# ## Merging with district and sector shape files
# The next step is to merge our GP data with the district and sector shape files from earlier. We will have to merge three data frames together, while removing the irelevant data.

# %%
merged = pd.merge(hyposplit,sectors,on='Sector',how='outer')   # Firstly merge with sector data to get their geometries
merged = merged.head(39)                                       # Keep only rows that contain our GP data
merged = pd.merge(merged,districts,on='District',how='outer')  # Now merge with district data for their geometries
merged = merged.head(39)                                       # Again we keep only rows with our GP data

# %%
merged.head(5)
# Out:
#    Practice Code               Practice Name District Sector  OBJECTID_x  \
# 0        60073.0  Nalagatla Medical Practice      NaN  G33 6       405.0
# 1        60073.0  Nalagatla Medical Practice      NaN  G33 1       400.0
# 2        60073.0  Nalagatla Medical Practice      NaN  G66 5       467.0
# 3        60073.0  Nalagatla Medical Practice      NaN  G67 4       473.0
# 4        60073.0  Nalagatla Medical Practice      NaN  G69 0       476.0
#
#    Shape_Leng_x  Shape_Area_x  \
# 0  13187.797508  5.534912e+06
# 1  17953.029367  4.046323e+06
# 2  24961.336020  9.534817e+06
# 3  27310.140398  1.185204e+07
# 4   9989.427151  3.937652e+06
#
#                                           geometry_x  OBJECTID_y  \
# 0  POLYGON ((267475.808 668112.939, 267522.051 66...         NaN
# 1  POLYGON ((263854.270 669613.771, 263879.607 66...         NaN
# 2  POLYGON ((270799.000 673152.000, 270704.000 67...         NaN
# 3  MULTIPOLYGON (((274681.560 672719.400, 274681....         NaN
# 4  POLYGON ((270896.401 672086.297, 270904.003 67...         NaN
#
#    Shape_Leng_y  Shape_Area_y geometry_y
# 0           NaN           NaN       None
# 1           NaN           NaN       None
# 2           NaN           NaN       None
# 3           NaN           NaN       None
# 4           NaN           NaN       None

# %% [markdown]
# Notice that we now have two sets of data, with suffixes x and y. In particular, we can merge geometry_x and geometry_y together. We only demonstrate with the geometry data here, but this of course can be done with other columns as well such as Shape_Area.

# %%
# Create a dummy data frame without the geometry columns
no_geometry = merged.drop('geometry_x',1)
no_geometry = no_geometry.drop('geometry_y',1)
# Out:
# C:\Users\yeehil01\AppData\Local\Temp\ipykernel_22492\1354355844.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   no_geometry = merged.drop('geometry_x',1)
# C:\Users\yeehil01\AppData\Local\Temp\ipykernel_22492\1354355844.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   no_geometry = no_geometry.drop('geometry_y',1)

# %%
# Merge the geometry columns, and also merge with our dummy data frame
# Rename the merged column back to Geometry
clean_merged = pd.concat([no_geometry,merged['geometry_x'].combine_first(merged['geometry_y'])],
                        axis=1)
clean_merged.rename(columns={'geometry_x':'geometry'},inplace=True)

# %%
clean_merged
# Out:
#     Practice Code                    Practice Name District Sector  \
# 0         60073.0       Nalagatla Medical Practice      NaN  G33 6
# 1         60073.0       Nalagatla Medical Practice      NaN  G33 1
# 2         60073.0       Nalagatla Medical Practice      NaN  G66 5
# 3         60073.0       Nalagatla Medical Practice      NaN  G67 4
# 4         60073.0       Nalagatla Medical Practice      NaN  G69 0
# 5         60073.0       Nalagatla Medical Practice      NaN  G69 8
# 26  9.683538e+07  POLYGON ((258374.503 683849.000, 258376.498 68...
# 27  3.462987e+07  MULTIPOLYGON (((274681.560 672719.400, 274681....
# 28  1.881358e+07  MULTIPOLYGON (((274793.013 672904.383, 274812....
# 29  1.881358e+07  MULTIPOLYGON (((274793.013 672904.383, 274812....
# 30  3.155747e+07  POLYGON ((270896.401 672086.297, 270904.003 67...
# 31  3.155747e+07  POLYGON ((270896.401 672086.297, 270904.003 67...
# 32  2.299439e+07  POLYGON ((269044.911 663276.026, 268999.508 66...
# 33  3.575193e+07  POLYGON ((263674.700 661654.403, 263700.796 66...
# 34  3.575193e+07  POLYGON ((263674.700 661654.403, 263700.796 66...
# 35  3.575193e+07  POLYGON ((263674.700 661654.403, 263700.796 66...
# 36  1.107882e+07  POLYGON ((262085.201 663425.096, 262112.698 66...
# 37  1.107882e+07  POLYGON ((262085.201 663425.096, 262112.698 66...
# 38  7.021635e+07  POLYGON ((260320.000 655362.000, 260361.883 65...

# %% [markdown]
# Double check the dimension (number of rows should be 39). This should match with the dimension of the original GP data.

# %%
clean_merged.shape
# Out:
# (39, 11)

# %% [markdown]
# Sort the data according to the GP practices.

# %%
clean_merged = clean_merged.sort_values(by=['Practice Code'])

# %%
clean_merged
# Out:
#     Practice Code                    Practice Name District Sector  \
# 0         60073.0       Nalagatla Medical Practice      NaN  G33 6
# 1         60073.0       Nalagatla Medical Practice      NaN  G33 1
# 2         60073.0       Nalagatla Medical Practice      NaN  G66 5
# 3         60073.0       Nalagatla Medical Practice      NaN  G67 4
# 4         60073.0       Nalagatla Medical Practice      NaN  G69 0
# 5         60073.0       Nalagatla Medical Practice      NaN  G69 8
# 6         60073.0       Nalagatla Medical Practice      NaN  G69 9
# 22        60092.0            The Stonelaw Practice      G62    NaN
# 23        60092.0            The Stonelaw Practice      G63    NaN
# 24        60092.0            The Stonelaw Practice      G64    NaN
# 25        60092.0            The Stonelaw Practice      G65    NaN
# 26        60092.0            The Stonelaw Practice      G66    NaN
# 32        60092.0            The Stonelaw Practice      G71    NaN
# 28        60092.0            The Stonelaw Practice      G68    NaN
# 30        60092.0            The Stonelaw Practice      G69    NaN
# 21        60092.0            The Stonelaw Practice      G61    NaN
# 33        60092.0            The Stonelaw Practice      G72    NaN
# 36        60092.0            The Stonelaw Practice      G73    NaN
# 27        60092.0            The Stonelaw Practice      G67    NaN
# 20        60092.0            The Stonelaw Practice      G60    NaN
# 19        60092.0            The Stonelaw Practice      G45    NaN
# 18        60092.0            The Stonelaw Practice      G44    NaN
# 16        60092.0            The Stonelaw Practice      G40    NaN
# 38        60092.0            The Stonelaw Practice      G76    NaN
# 17        60092.0            The Stonelaw Practice      G42    NaN
# 8         60177.0  The Craigallian Avenue Practice      NaN  G72 8
# 7         60177.0  The Craigallian Avenue Practice      NaN  G72 7
# 34        60209.0          Ardoch Medical Practice      G72    NaN
# 11        66666.0                 Hypothetical One      NaN  G71 5
# C:\Users\yeehil01\AppData\Local\Temp\ipykernel_22492\701948688.py:1: FutureWarning: CRS mismatch between CRS of the passed geometries and 'crs'. Use 'GeoDataFrame.set_crs(crs, allow_override=True)' to overwrite CRS or 'GeoDataFrame.to_crs(crs)' to reproject geometries. CRS mismatch will raise an error in the future versions of GeoPandas.
#   clean_merged = gpd.GeoDataFrame(clean_merged, crs="EPSG:4326")

# %%
clean_merged.plot('Practice Name',facecolor='none',cmap=plt.cm.jet,legend=True,legend_kwds={'bbox_to_anchor':(2.2, 1)})
plt.savefig('geography_test.pdf', bbox_inches='tight')

# %%
clean_merged.to_file('./undissolved.shp') # save this to shape file
# Out:
# C:\Users\yeehil01\AppData\Local\Programs\Python\Python310\lib\site-packages\geopandas\io\file.py:362: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
# C:\Users\yeehil01\AppData\Local\Temp\ipykernel_22492\4268178294.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   clean_merged.to_file('./undissolved.shp') # save this to shape file

# %% [markdown]
# ## Merging postcode sectors
# We are interested in the GP boundaries instead of individual postcode districts and sectors. Therefore, we dissolve the boundaries and merge the geographies.

# %%
dissolved = clean_merged.dissolve(by='Practice Code')

# %%
dissolved
# Out:
#                                                         geometry  \
# Practice Code
# 60073.0        MULTIPOLYGON (((263951.414 669614.226, 263951....
# 60092.0        MULTIPOLYGON (((237382.680 686244.650, 237381....
# 60177.0        POLYGON ((267795.000 658455.000, 267839.000 65...
# 60209.0        POLYGON ((263674.700 661654.403, 263700.796 66...
# 66666.0        MULTIPOLYGON (((263707.027 661543.484, 263716....
# 66667.0        MULTIPOLYGON (((265970.305 654873.266, 265938....
#
#                                  Practice Name District Sector  OBJECTID_x  \
# Practice Code
# 60073.0             Nalagatla Medical Practice     None  G33 6       405.0
# 60092.0                  The Stonelaw Practice      G62   None         NaN
# 60177.0        The Craigallian Avenue Practice     None  G72 8       488.0
# 60209.0                Ardoch Medical Practice      G72   None         NaN
# 66666.0                       Hypothetical One      G73  G71 5       481.0
# 66667.0                       Hypothetical Two      G69  G74 4       498.0
#
#                Shape_Leng_x  Shape_Area_x  OBJECTID_y  Shape_Leng_y  \
# Practice Code
# 60073.0        13187.797508  5.534912e+06         NaN           NaN
# 60092.0                 NaN           NaN       165.0  34929.342069
# 60177.0        21208.639820  1.257245e+07         NaN           NaN
# 60209.0                 NaN           NaN       174.0  38454.360455
# 66666.0        13157.246865  4.248974e+06       175.0  25828.118056
# 66667.0        18136.275165  6.806923e+06       172.0  44816.170187
#
#                Shape_Area_y
# Practice Code
# 60073.0                 NaN
# 60092.0        3.612370e+07
# 60177.0                 NaN
# 60209.0        3.575193e+07
# 66666.0        1.107882e+07
# 66667.0        3.155747e+07

# %% [markdown]
# As seen, the results are now grouped by GP Practice Code. We can plot again to have a look. Some boundaries have disappeared now, as expected.

# %%
dissolved.plot('Practice Name',facecolor='none',cmap=plt.cm.jet,legend=True,legend_kwds={'bbox_to_anchor':(2.2, 1)})
plt.savefig('geography_dissolved.pdf', bbox_inches='tight')

# %% [markdown]
# Finally, we can save this to a shape file and read in using ArcPro.

# %%
dissolved.to_file('./geographies.shp')
# Out:
# C:\Users\yeehil01\AppData\Local\Temp\ipykernel_22492\3653566836.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   dissolved.to_file('./geographies.shp')
